# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
from tqdm import tqdm, tqdm_notebook
import nltk
nltk.download('stopwords')
nltk.download('punkt')
import functools
import matplotlib.pyplot as plt

pd.options.display.max_columns = 200
pd.options.mode.chained_assignment = None

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
stop = set(stopwords.words('english'))
from string import punctuation

from collections import Counter
import re
import numpy as np

from tqdm import tqdm_notebook
tqdm_notebook().pandas()

from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer

def getCategorys():
    return  ['business', 'health', 'technology', 'entertainment', 'science', 'sports']

def setApiKey():
    return '498d86e3c11b4142ad84982f58dba794'

def nameMedia(source, m):
    try: 
        return m[source]
    except:
        return 'Kompas.com'

def url(category):
    apiKey = setApiKey()
    source_url = 'https://newsapi.org/v2/top-headlines?country=id&category='+str(category)+'&apiKey='+str(apiKey)
    data = requests.get(source_url).json()
    return data

def getDailyNews():
    categorys = getCategorys()
    key = setApiKey()
    url = 'https://newsapi.org/v2/top-headlines?country=id&category={0}&apiKey={1}'
    responses = []
    for i, category in tqdm_notebook(enumerate(categorys), total=len(categorys)):
        try:
            u = url.format(category, key)
        except:
            u = url.format('business', key)
        
        response = requests.get(u)
        r = response.json()   
        try:
            for article in r['articles']:
                article['category'] = category
                article['source'] = article['source']['name']
            responses.append(r)
        except:
            print('Rate limit exceeded ... please wait and retry in 6 hours')
            return None
        
    articles = list(map(lambda r: r['articles'], responses))
    articles = list(reduce(lambda x,y: x+y, articles))
    
    news = pd.DataFrame(articles)
    news = news.drop_duplicates()
    news.reset_index(inplace=True, drop=True)
    news['scraping_date'] = datetime.now()
    
    try:
        exportData = pd.read_csv('./news-indo.csv')
        exportData = exportData.append(news)
        #exportData = exportData.drop_duplicates('url')
        exportData.reset_index(inplace=True, drop=True)
        exportData.to_csv('./news-indo.csv', encoding='urf-8', index=False)
    except:
        news.to_csv('./news-indo.csv', index=False, encoding='utf-8')
        
    print('Done')

getDailyNews()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\haidinata\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\haidinata\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6), HTML(value='')))
# Done

# %%
data = pd.read_csv('./news-indo.csv')
data.source.value_counts(normalize=True).plot(kind='bar', grid=True, figsize=(15, 10))

# %%
data = data.drop_duplicates('description')

# %%
data = data[~data['description'].isnull()]
data.shape
# Out:
# (120, 10)

# %%
data.description.map(len)
# Out:
# 0       82
# 1      139
# 2      122
# 3      115
# 4      114
# 5      109
# 6      204
# 7      100
# 8      160
# 9      156
# 10     144
# 11     142
# 12     130
# 13     121
# 14      93
# 15     109
# 16      53
# 17     110
# 18     146
# 19     131
# 20      95
# 21     155
# 22     131
# 23     142
# 24      76
# 25     260
# 26     260
# 27     154
# 28     105
# 29     173
#       ...
# 90      74
# 91      97
# 92     146
# 93      36
# 94      88
# 95      94
# 96     124
# 97      65
# 98      59
# 99      97
# 100    126
# 101    174
# 102    147
# 103    133
# 104    196
# 105    146
# 106    159
# 107     83
# 108    103
# 109    118
# 110    113
# 111    116
# 112    133
# 113    121
# 114    100
# 115    174
# 116    145
# 117    121
# 118     73
# 119     63
# Name: description, Length: 120, dtype: int64

# %%
data = data[(data.description.map(len) > 60) & (data.description.map(len) < 200)]
data.reset_index(inplace=True, drop=True)

data.shape
# Out:
# (107, 10)

# %%
data.description.map(len).hist(figsize=(15, 5), bins=100)

# %%
data = data.sample(100, random_state=50)
data.reset_index(inplace=True, drop=True)
data.head(3)
# Out:
#              author  category  \
# 0   Anisa Widiarini    health
# 1  Erlangga Djumena  business
# 2      Lucas Aditya    sports
#
#                                              content  \
# 0  VIVA  Sakit Jantung jadi salah satu penyakit t...
# 1  JAKARTA, KOMPAS.com - Badan Pusat Statistik me...
# 2  Manchester - Harry Maguire mendapatkan pujian ...
#
#                                          description           publishedAt  \
# 0  Berita 4 Daftar Makanan dan Minuman yang Picu ...  2019-08-15T00:18:44Z
# 1  kenaikan impor ini disumbang oleh naiknya impo...  2019-08-15T08:19:00Z
# 2  Harry Maguire mendapatkan pujian dari legenda ...  2019-08-15T12:45:31Z
#
#        source                                              title  \
# 0  Viva.co.id  4 Daftar Makanan dan Minuman yang Picu Milenia...
# 1  Kompas.com  Impor Juli 2019 Naik, China Pemasok Barang Imp...
# 2   Detik.com  'Harry Maguire Terlahir untuk Man United' - de...
#
#                                                  url  \
# 0  https://www.viva.co.id/gaya-hidup/kesehatan-in...
# 1  https://money.kompas.com/read/2019/08/15/15190...
# 2  https://sport.detik.com/sepakbola/liga-inggris...
#
#                                           urlToImage  \
# 0  https://thumb.viva.co.id/media/frontend/thumbs...
# 1  https://asset.kompas.com/crop/0x0:1000x667/780...
# 2  https://akcdn.detik.net.id/api/wm/2019/08/12/3...
#
#                 scraping_date
# 0  2019-08-16 05:31:29.543058
# 1  2019-08-16 05:31:29.543058
# 2  2019-08-16 05:31:29.543058

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
 
factory = StopWordRemoverFactory()
stop_words = factory.get_stop_words()
len(stop_words)
# Out:
# 809

# %%
def _removeNonAscii(s): 
    return "".join(i for i in s if ord(i)<128)

def clean_text(text):
    text = text.lower()
    text = re.sub(r'\W+', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r"\\", "", text)
    text = re.sub(r"\'", "", text)    
    text = re.sub(r"\"", "", text)
    text = re.sub(r"com", "", text)
    text = re.sub(r"teercaya", "", text)
    text = re.sub('[^a-zA-Z ?*$!]+', '', text)
    text = re.sub(" \d+", " ", text)
    text = re.sub(r'[0-9]+', '', text)
    text = _removeNonAscii(text)
    text = text.strip()
    
    return text

def tokenizer(text):
    text = clean_text(text)
    tokens =  [word_tokenize(sent) for sent in sent_tokenize(text)]
    #memberikan koma di setiap kata
    tokens = list(functools.reduce(lambda x,y: x+y, tokens))
    #filter kata penghubung
    tokens = list(filter(lambda token: token not in (stop_words + list(punctuation)) , tokens))
    
    return tokens

# %%
data['description'] = data['description'].map(lambda d: str(d))
data['tokens'] = data['description'].progress_map(lambda d: tokenizer(d))
# Out:
# HBox(children=(IntProgress(value=0, max=120), HTML(value='')))

# %%
for description, tokens in zip(data['description'].head(5), data['tokens'].head(5)):
    print('description:', description)
    print('tokens:', tokens)
    print()
# Out:
# description: Bank BRI akan menerbitkan surat utang sekitar Rp 5 triliun pada Oktober mendatang.
# tokens: ['bank', 'bri', 'menerbitkan', 'surat', 'utang', 'triliun', 'oktober']
#
# description: Komisaris WAE Darwin Maspolim yang tersangkut korupsi memiliki bisnis otomotif yaitu meniagakan mobil-mobil mewah berharga miliaran rupiah.
# tokens: ['komisaris', 'wae', 'darwin', 'maspolim', 'tersangkut', 'korupsi', 'memiliki', 'bisnis', 'otomotif', 'meniagakan', 'mobil', 'mobil', 'mewah', 'berharga', 'miliaran', 'rupiah']
#
# description: Penggunaan bahan bakar biodiesel B20 belum setahun diterapkan, namun Presiden Joko Widodo ingin RI loncat langsung ke B30 dan B50.
# tokens: ['penggunaan', 'bahan', 'bakar', 'biodiesel', 'setahun', 'diterapkan', 'presiden', 'joko', 'widodo', 'ri', 'loncat']
#
# description: Kewajiban jangka pendek Agung Podomoro Land capai Rp 6,2 triliun, sedangkan kas dan setara kas hanya Rp 666 miliar.
# tokens: ['kewajiban', 'jangka', 'pendek', 'agung', 'podomoro', 'land', 'capai', 'triliun', 'kas', 'setara', 'kas', 'miliar']
#
# description: Mitsubishi New Triton telah diperkenalkan Juli lalu. Yuk lihat aksi Pikap 4x4 di sirkuit off-road Pagedangan, BSD.
# tokens: ['mitsubishi', 'new', 'triton', 'diperkenalkan', 'juli', 'yuk', 'aksi', 'pikap', 'sirkuit', 'off', 'road', 'pagedangan', 'bsd']

# %%
def keywords(category):
    tokens = data[data['source'] == category]['tokens']
    alltokens = []
    for token_list in tokens:
        alltokens += token_list
    counter = Counter(alltokens)
    
    return counter.most_common(5)

for source in set(data['source']):
    print('source:', source)
    print('top 10 keywords:', keywords(source))
    print('---')
# Out:
# source: Bolasport.com
# top 10 keywords: [('penyerang', 1), ('persija', 1), ('jakarta', 1), ('marko', 1), ('simic', 1)]
# ---
# source: Pikiran-rakyat.com
# top 10 keywords: [('hiv', 2), ('aids', 2), ('positif', 2), ('data', 1), ('dinkes', 1)]
# ---
# source: Tabloidpulsa.co.id
# top 10 keywords: [('myrepublic', 1), ('sony', 1), ('indonesia', 1), ('tawarkan', 1), ('paket', 1)]
# ---
# source: Dream.co.id
# top 10 keywords: [('glenn', 1), ('fredly', 1), ('dikabarkan', 1), ('melangsungkan', 1), ('lamaran', 1)]
# ---
# source: Cnbcindonesia.com
# top 10 keywords: [('bank', 2), ('harga', 2), ('saham', 2), ('bri', 1), ('menerbitkan', 1)]
# ---
# source: Merdeka.com
# top 10 keywords: [('anak', 2), ('dokter', 2), ('imunisasi', 1), ('diwajibkan', 1), ('pemerintah', 1)]
# ---
# source: Tribunnews.com
# top 10 keywords: [('whatsapp', 3), ('buah', 2), ('foto', 2), ('ramalan', 2), ('zodiak', 2)]
# ---
# source: Suara.com
# top 10 keywords: [('mad', 1), ('mike', 1), ('terbang', 1), ('roket', 1), ('buatannya', 1)]
# ---
# source: Brilio.net
# top 10 keywords: [('peneliti', 1), ('nasa', 1), ('berhasil', 1), ('memecahkan', 1), ('persatu', 1)]
# ---
# source: Motorplus-online.com
# top 10 keywords: [('honda', 1), ('cbr', 1), ('streetfire', 1), ('warna', 1), ('razor', 1)]
# ---
# source: Beritasatu.com
# top 10 keywords: [('proyek', 1), ('runway', 1), ('dimanfaatkan', 1), ('mendukung', 1), ('bandara', 1)]
# ---
# source: Winnetnews.com
# top 10 keywords: [('kepala', 3), ('sakit', 2), ('tidur', 1), ('hipertensi', 1), ('alias', 1)]
# ---
# source: Viva.co.id
# top 10 keywords: [('berita', 9), ('terbaru', 9), ('sumber', 9), ('bikin', 2), ('minuman', 2)]
# ---
# source: Cumicumi.com
# top 10 keywords: [('cumicumi', 1), ('baim', 1), ('bagikan', 1), ('cerita', 1), ('mengejutkan', 1)]
# ---
# source: Okezone.com
# top 10 keywords: [('terbesar', 2), ('sturgeon', 2), ('turnamen', 1), ('esport', 1), ('dota', 1)]
# ---
# source: Grid.id
# top 10 keywords: [('bumi', 2), ('donna', 1), ('harun', 1), ('menikah', 1), ('lelaki', 1)]
# ---
# source: Ayobandung.com
# top 10 keywords: [('indonesia', 3), ('kereta', 2), ('api', 2), ('anak', 2), ('rangka', 1)]
# ---
# source: Femina.co.id
# top 10 keywords: [('menjaga', 1), ('tubuh', 1), ('sehat', 1), ('kota', 1), ('tingkat', 1)]
# ---
# source: 1health.id
# top 10 keywords: [('kenali', 1), ('faktor', 1), ('risiko', 1), ('penyebab', 1), ('penyakit', 1)]
# ---
# source: Gatra.com
# top 10 keywords: [('berita', 1), ('politik', 1), ('ekonomi', 1), ('nasional', 1)]
# ---
# source: Hitekno.com
# top 10 keywords: [('bumi', 2), ('hujan', 1), ('meteor', 1), ('perseid', 1), ('agustus', 1)]
# ---
# source: Reportasee.com
# top 10 keywords: [('medan', 1), ('magnet', 1), ('butuh', 1), ('tahun', 1), ('pembalikan', 1)]
# ---
# source: Idntimes.com
# top 10 keywords: [('duel', 1), ('sengit', 1), ('saudara', 1), ('segmen', 1), ('menengah', 1)]
# ---
# source: Youtube.com
# top 10 keywords: [('note', 3), ('ngimpi', 1), ('gue', 1), ('megang', 1), ('walopun', 1)]
# ---
# source: Sindonews.com
# top 10 keywords: [('men', 2), ('wolverine', 1), ('satunya', 1), ('karakter', 1), ('selamat', 1)]
# ---
# source: Bola.net
# top 10 keywords: [('chelsea', 2), ('legenda', 2), ('rasisme', 1), ('hilang', 1), ('dunia', 1)]
# ---
# source: Cnnindonesia.com
# top 10 keywords: [('otomotif', 3), ('mobil', 3), ('iphone', 2), ('terbaru', 2), ('astronom', 2)]
# ---
# source: Kompas.com
# top 10 keywords: [('fase', 2), ('industri', 2), ('temuan', 1), ('manfaat', 1), ('akar', 1)]
# ---
# source: Liputan6.com
# top 10 keywords: [('vitamin', 1), ('tubuh', 1), ('menurunkan', 1), ('risiko', 1), ('terkena', 1)]
# ---
# source: Tabloidbintang.com
# top 10 keywords: [('kulit', 3), ('kering', 2), ('seringkali', 1), ('disamakan', 1), ('dehidrasi', 1)]
# ---
# source: Detik.com
# top 10 keywords: [('menteri', 2), ('jok', 2), ('saham', 2), ('turun', 2), ('as', 2)]
# ---
# source: Tirto.id
# top 10 keywords: [('gb', 3), ('meter', 2), ('beli', 1), ('paket', 1), ('data', 1)]
# ---
# source: Bisnis.com
# top 10 keywords: [('epilepsi', 3), ('rutin', 2), ('mcu', 2), ('penyakit', 2), ('pemeriksaan', 1)]
# ---
# source: Jawapos.com
# top 10 keywords: [('asemrowo', 2), ('belas', 1), ('perwakilan', 1), ('kecamatan', 1), ('puskesmas', 1)]
# ---
# source: Gridoto.com
# top 10 keywords: [('yamaha', 2), ('all', 2), ('new', 2), ('ixion', 2), ('indonesia', 1)]
# ---
# source: Katadata.co.id
# top 10 keywords: [('kas', 2), ('kewajiban', 1), ('jangka', 1), ('pendek', 1), ('agung', 1)]
# ---
# source: Republika.co.id
# top 10 keywords: [('peningkatan', 1), ('kemakmuran', 1), ('kurangnya', 1), ('aktivitas', 1), ('fisik', 1)]
# ---
# source: Bola.com
# top 10 keywords: [('dianggap', 1), ('bermain', 1), ('pubg', 1), ('mobile', 1), ('uefa', 1)]
# ---
# source: Tempo.co
# top 10 keywords: [('ria', 1), ('ricis', 1), ('mengakui', 1), ('video', 1), ('pamit', 1)]
# ---
# source: Krjogja.com
# top 10 keywords: [('amerika', 1), ('krjogja', 1), ('universitas', 1), ('cornell', 1), ('berhasil', 1)]
# ---
# source: Www.tek.id
# top 10 keywords: [('snapdragon', 2), ('perangkat', 2), ('rumor', 1), ('ponsel', 1), ('realme', 1)]
# ---
# source: Selular.id
# top 10 keywords: [('smartfren', 2), ('mural', 2), ('raksasa', 2), ('jakarta', 1), ('selular', 1)]
# ---

# %%
vectorizer = TfidfVectorizer(min_df=3, analyzer='word', ngram_range=(1, 5))
vz = vectorizer.fit_transform(list(data['tokens'].map(lambda tokens: ' '.join(tokens))))

vz.shape
# Out:
# (120, 35)

# %%
tfidf = dict(zip(vectorizer.get_feature_names(), vectorizer.idf_))
tfidf = pd.DataFrame(columns=['tfidf']).from_dict(dict(tfidf), orient='index')
tfidf.columns = ['tfidf']

def plot_word_cloud(terms):
    text = terms.index
    text = ' '.join(list(text))
    wordcloud = WordCloud(max_font_size=40).generate(text)
    plt.figure(figsize=(15, 15))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()
    
plot_word_cloud(tfidf.sort_values(by=['tfidf'], ascending=True).head(40))
